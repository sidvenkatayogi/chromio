# %%
import pandas as pd
import ast
import os
from pathlib import Path

# %%
# Configuration
RESULTS_DIR = Path('results')

def is_all_black(palette_str):
    """Check if a palette is all black (invalid response)."""
    try:
        palette = ast.literal_eval(palette_str)
        return all(c.lower() == '#000000' for c in palette)
    except:
        return True  # Treat parse errors as invalid

def load_and_filter_csv(filepath):
    """Load CSV and filter out all-black palettes."""
    df = pd.read_csv(filepath)
    valid_mask = ~df['generated_palette'].apply(is_all_black)
    return df, df[valid_mask]

# %%
# Find all CSV files
csv_files = sorted(RESULTS_DIR.glob('*.csv'))
print(f"Found {len(csv_files)} result files:\n")
for f in csv_files:
    print(f"  - {f.name}")
# Out:
# Found 16 result files:
#
#   - eval_fireworks_accounts_fireworks_models_gpt-oss-20b_20260103_024651.csv
#   - eval_fireworks_accounts_fireworks_models_llama-v3p1-8b-instruct_20260109_204850.csv
#   - eval_fireworks_accounts_fireworks_models_llama-v3p1-8b-instruct_HSL_20260110_142344.csv
#   - eval_fireworks_accounts_fireworks_models_llama-v3p3-70b-instruct_20260103_021738.csv
#   - eval_fireworks_accounts_fireworks_models_qwen2p5-vl-32b-instruct_20260103_133925.csv
#   - eval_fireworks_accounts_fireworks_models_qwen3-8b_20260103_135722.csv
#   - eval_fireworks_accounts_fireworks_models_qwen3-8b_CIELAB_20260110_150041.csv
#   - eval_fireworks_accounts_fireworks_models_qwen3-8b_HSL_20260110_142641.csv
#   - eval_fireworks_accounts_sidvenkatayogi_deployedModels_rft-fhiaqwgu-0-1-ka2pgv73_20260109_023624.csv
#   - eval_fireworks_accounts_sidvenkatayogi_models_artist-qwen2p5-vl-7b-instruct_20260109_195632.csv
#   - eval_fireworks_accounts_sidvenkatayogi_models_artist-qwen3-8b-5-5-8_20260109_195746.csv
#   - eval_fireworks_accounts_sidvenkatayogi_models_artist-v2_20260109_201255.csv
#   - eval_fireworks_accounts_sidvenkatayogi_models_artist-v3-llama-3p1-8b_20260109_151631.csv
#   - eval_openai_gpt-4o-mini_20260103_024052.csv
#   - eval_openai_gpt-4o_20260103_012027.csv
#   - eval_openai_gpt-5-mini_20260103_021759.csv

# %%
# Generate summary statistics for each CSV
summaries = []

for csv_file in csv_files:
    df_all, df_valid = load_and_filter_csv(csv_file)
    
    model = df_all['model'].iloc[0] if len(df_all) > 0 else 'unknown'
    provider = df_all['provider'].iloc[0] if len(df_all) > 0 else 'unknown'
    
    summary = {
        'file': csv_file.name,
        'provider': provider,
        'model': model.split('/')[-1] if '/' in model else model,  # Short name
        'total_samples': len(df_all),
        'valid_samples': len(df_valid),
        'filtered_out': len(df_all) - len(df_valid),
        'valid_pct': len(df_valid) / len(df_all) * 100 if len(df_all) > 0 else 0,
    }
    
    if len(df_valid) > 0:
        summary['mean_norm_D'] = df_valid['norm_D'].mean()
        summary['mean_norm_S'] = df_valid['norm_S'].mean()
        summary['mean_score_R'] = df_valid['score_R'].mean()
        summary['std_norm_D'] = df_valid['norm_D'].std()
        summary['std_norm_S'] = df_valid['norm_S'].std()
        summary['std_score_R'] = df_valid['score_R'].std()
        
        # Raw scores (new fields)
        summary['mean_gt_diversity'] = df_valid['gt_diversity'].mean()
        summary['mean_gen_diversity'] = df_valid['gen_diversity'].mean()
        summary['mean_raw_dccw'] = df_valid['raw_dccw'].mean()
        summary['mean_diversity_diff'] = df_valid['diversity_diff'].mean()
        summary['std_raw_dccw'] = df_valid['raw_dccw'].std()
    else:
        summary['mean_norm_D'] = None
        summary['mean_norm_S'] = None
        summary['mean_score_R'] = None
        summary['std_norm_D'] = None
        summary['std_norm_S'] = None
        summary['std_score_R'] = None
        summary['mean_gt_diversity'] = None
        summary['mean_gen_diversity'] = None
        summary['mean_raw_dccw'] = None
        summary['mean_diversity_diff'] = None
        summary['std_raw_dccw'] = None
    
    summaries.append(summary)

summary_df = pd.DataFrame(summaries)
summary_df
# Out:
#                                                  file   provider  \
# 0   eval_fireworks_accounts_fireworks_models_gpt-o...  fireworks
# 1   eval_fireworks_accounts_fireworks_models_llama...  fireworks
# 2   eval_fireworks_accounts_fireworks_models_llama...  fireworks
# 3   eval_fireworks_accounts_fireworks_models_llama...  fireworks
# 4   eval_fireworks_accounts_fireworks_models_qwen2...  fireworks
# 5   eval_fireworks_accounts_fireworks_models_qwen3...  fireworks
# 6   eval_fireworks_accounts_fireworks_models_qwen3...  fireworks
# 7   eval_fireworks_accounts_fireworks_models_qwen3...  fireworks
# 8   eval_fireworks_accounts_sidvenkatayogi_deploye...  fireworks
# 9   eval_fireworks_accounts_sidvenkatayogi_models_...  fireworks
# 10  eval_fireworks_accounts_sidvenkatayogi_models_...  fireworks
# 11  eval_fireworks_accounts_sidvenkatayogi_models_...  fireworks
# 12  eval_fireworks_accounts_sidvenkatayogi_models_...  fireworks
# 13        eval_openai_gpt-4o-mini_20260103_024052.csv     openai
# 14             eval_openai_gpt-4o_20260103_012027.csv     openai
# 15         eval_openai_gpt-5-mini_20260103_021759.csv     openai
#
#                             model  total_samples  valid_samples  filtered_out  \
# 0                     gpt-oss-20b            100             78            22
# 1          llama-v3p1-8b-instruct            100            100             0
# 2      llama-v3p1-8b-instruct_HSL            100             99             1
# 3         llama-v3p3-70b-instruct            100             88            12
# 4         qwen2p5-vl-32b-instruct            100            100             0
# 5                        qwen3-8b            100            100             0
# 6                 qwen3-8b_CIELAB            100            100             0
# 7                    qwen3-8b_HSL            100             99             1
# 8       rft-fhiaqwgu-0-1-ka2pgv73            100            100             0
# 9   artist-qwen2p5-vl-7b-instruct            100            100             0
# 10          artist-qwen3-8b-5-5-8            100            100             0
# 11                      artist-v2            100            100             0
# 12         artist-v3-llama-3p1-8b            100            100             0
# 13                    gpt-4o-mini            100            100             0
# 14                         gpt-4o            100            100             0
# 15                     gpt-5-mini            100            100             0
#
#     valid_pct  mean_norm_D  mean_norm_S  mean_score_R  std_norm_D  std_norm_S  \
# 0        78.0     0.588642     0.532236      0.475971    0.333715    0.292295
# 1       100.0     0.619746     0.462084      0.457575    0.295903    0.295393
# 2        99.0     0.615814     0.478072      0.477468    0.301995    0.281963
# 3        88.0     0.601410     0.502575      0.479140    0.309362    0.279820
# 4       100.0     0.529314     0.463592      0.414670    0.336855    0.276094
# 5       100.0     0.623319     0.440834      0.435674    0.317901    0.292838
# 6       100.0     0.605522     0.470463      0.458340    0.302189    0.286058
# 7        99.0     0.615814     0.478072      0.477468    0.301995    0.281963
# 8       100.0     0.622311     0.488868      0.468576    0.314691    0.285788
# 9       100.0     0.562037     0.415719      0.388528    0.337948    0.305584
# 10      100.0     0.638413     0.459637      0.464881    0.303875    0.300642
# 11      100.0     0.607634     0.494418      0.472248    0.309135    0.284560
# 12      100.0     0.604483     0.482864      0.476185    0.319245    0.304772
# 13      100.0     0.568782     0.470680      0.453859    0.316705    0.282946
# 14      100.0     0.583893     0.518969      0.475552    0.307444    0.288068
# 15      100.0     0.533857     0.558584      0.466177    0.347128    0.262529
#
#     std_score_R  mean_gt_diversity  mean_gen_diversity  mean_raw_dccw  \
# 0      0.297463          28.043912           29.436784      26.113184
# 1      0.280090          27.522209           30.399192      28.591253
# 2      0.267287          27.812907           29.735451      27.224976
# 3      0.277015          27.289118           30.551090      26.363621
# 4      0.278038          27.522209           37.501595      27.688208
# 5      0.287413          27.522209           29.770412      29.653078
# 6      0.284723          27.535808           26.137633      27.987131
# 7      0.267287          27.812907           29.735451      27.224976
# 8      0.286824          27.522209           31.585994      27.353852
# 9      0.306527          27.522209           29.961306      31.177123
# 10     0.291307          27.522209           31.970482      28.651155
# 11     0.279174          27.522209           32.352387      27.266602
# 12     0.304607          27.522209           30.124802      27.815703
# 13     0.281088          27.522209           33.059576      27.946879
# 14     0.284232          27.522209           31.908932      26.112353
# 15     0.301369          27.522209           35.681833      24.692585
#
#     mean_diversity_diff  std_raw_dccw
# 0             13.056241     12.465413
# 1             11.911222     12.673150
# 2             11.791401     10.453235
# 3             12.270499     10.388477
# 4             15.181804     10.141089
# 5             11.781996     13.571049
# 6             12.241840     11.717665
# 7             11.791401     10.453235
# 8             11.810915     11.791549
# 9             14.130257     14.771891
# 10            11.369766     12.981399
# 11            12.173670     11.595601
# 12            12.679523     12.540454
# 13            13.451164     11.414451
# 14            13.084647     11.138738
# 15            14.580646     10.432210

# %%
# Display detailed statistics per model
print("DETAILED SUMMARY STATISTICS (excluding all-black palettes)")
print("=" * 50)

for _, row in summary_df.iterrows():
    print(f"\n{'─' * 50}")
    print(f"Model: {row['model']}")
    print(f"Provider: {row['provider']}")
    print(f"{'─' * 50}")
    print(f"Total samples: {row['total_samples']}")
    print(f"Valid samples: {row['valid_samples']} ({row['valid_pct']:.1f}%)")
    print(f"Filtered out:  {row['filtered_out']}")
    
    if row['mean_score_R'] is not None:
        print(f"\nNormalized Metrics (mean ± std):")
        print(f"  norm_D:  {row['mean_norm_D']:.4f} ± {row['std_norm_D']:.4f}")
        print(f"  norm_S:  {row['mean_norm_S']:.4f} ± {row['std_norm_S']:.4f}")
        print(f"  score_R: {row['mean_score_R']:.4f} ± {row['std_score_R']:.4f}")
        
        print(f"\nRaw Scores:")
        print(f"  GT Diversity:  {row['mean_gt_diversity']:.2f}")
        print(f"  Gen Diversity: {row['mean_gen_diversity']:.2f}")
        print(f"  Raw DCCW:      {row['mean_raw_dccw']:.2f} ± {row['std_raw_dccw']:.2f}")
        print(f"  Diversity Δ:   {row['mean_diversity_diff']:.2f}")
    else:
        print("\n  No valid samples to compute metrics.")
# Out:
# DETAILED SUMMARY STATISTICS (excluding all-black palettes)
# ==================================================
#
# ──────────────────────────────────────────────────
# Model: gpt-oss-20b
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 78 (78.0%)
# Filtered out:  22
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.5886 ± 0.3337
#   norm_S:  0.5322 ± 0.2923
#   score_R: 0.4760 ± 0.2975
#
# Raw Scores:
#   GT Diversity:  28.04
#   Gen Diversity: 29.44
#   Raw DCCW:      26.11 ± 12.47
#   Diversity Δ:   13.06
#
# ──────────────────────────────────────────────────
# Model: llama-v3p1-8b-instruct
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6197 ± 0.2959
#   norm_S:  0.4621 ± 0.2954
#   score_R: 0.4576 ± 0.2801
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 30.40
#   Raw DCCW:      28.59 ± 12.67
#   Diversity Δ:   11.91
#
# ──────────────────────────────────────────────────
# Model: llama-v3p1-8b-instruct_HSL
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 99 (99.0%)
# Filtered out:  1
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6158 ± 0.3020
#   norm_S:  0.4781 ± 0.2820
#   score_R: 0.4775 ± 0.2673
#
# Raw Scores:
#   GT Diversity:  27.81
#   Gen Diversity: 29.74
#   Raw DCCW:      27.22 ± 10.45
#   Diversity Δ:   11.79
#
# ──────────────────────────────────────────────────
# Model: llama-v3p3-70b-instruct
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 88 (88.0%)
# Filtered out:  12
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6014 ± 0.3094
#   norm_S:  0.5026 ± 0.2798
#   score_R: 0.4791 ± 0.2770
#
# Raw Scores:
#   GT Diversity:  27.29
#   Gen Diversity: 30.55
#   Raw DCCW:      26.36 ± 10.39
#   Diversity Δ:   12.27
#
# ──────────────────────────────────────────────────
# Model: qwen2p5-vl-32b-instruct
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.5293 ± 0.3369
#   norm_S:  0.4636 ± 0.2761
#   score_R: 0.4147 ± 0.2780
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 37.50
#   Raw DCCW:      27.69 ± 10.14
#   Diversity Δ:   15.18
#
# ──────────────────────────────────────────────────
# Model: qwen3-8b
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6233 ± 0.3179
#   norm_S:  0.4408 ± 0.2928
#   score_R: 0.4357 ± 0.2874
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 29.77
#   Raw DCCW:      29.65 ± 13.57
#   Diversity Δ:   11.78
#
# ──────────────────────────────────────────────────
# Model: qwen3-8b_CIELAB
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6055 ± 0.3022
#   norm_S:  0.4705 ± 0.2861
#   score_R: 0.4583 ± 0.2847
#
# Raw Scores:
#   GT Diversity:  27.54
#   Gen Diversity: 26.14
#   Raw DCCW:      27.99 ± 11.72
#   Diversity Δ:   12.24
#
# ──────────────────────────────────────────────────
# Model: qwen3-8b_HSL
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 99 (99.0%)
# Filtered out:  1
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6158 ± 0.3020
#   norm_S:  0.4781 ± 0.2820
#   score_R: 0.4775 ± 0.2673
#
# Raw Scores:
#   GT Diversity:  27.81
#   Gen Diversity: 29.74
#   Raw DCCW:      27.22 ± 10.45
#   Diversity Δ:   11.79
#
# ──────────────────────────────────────────────────
# Model: rft-fhiaqwgu-0-1-ka2pgv73
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6223 ± 0.3147
#   norm_S:  0.4889 ± 0.2858
#   score_R: 0.4686 ± 0.2868
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 31.59
#   Raw DCCW:      27.35 ± 11.79
#   Diversity Δ:   11.81
#
# ──────────────────────────────────────────────────
# Model: artist-qwen2p5-vl-7b-instruct
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.5620 ± 0.3379
#   norm_S:  0.4157 ± 0.3056
#   score_R: 0.3885 ± 0.3065
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 29.96
#   Raw DCCW:      31.18 ± 14.77
#   Diversity Δ:   14.13
#
# ──────────────────────────────────────────────────
# Model: artist-qwen3-8b-5-5-8
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6384 ± 0.3039
#   norm_S:  0.4596 ± 0.3006
#   score_R: 0.4649 ± 0.2913
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 31.97
#   Raw DCCW:      28.65 ± 12.98
#   Diversity Δ:   11.37
#
# ──────────────────────────────────────────────────
# Model: artist-v2
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6076 ± 0.3091
#   norm_S:  0.4944 ± 0.2846
#   score_R: 0.4722 ± 0.2792
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 32.35
#   Raw DCCW:      27.27 ± 11.60
#   Diversity Δ:   12.17
#
# ──────────────────────────────────────────────────
# Model: artist-v3-llama-3p1-8b
# Provider: fireworks
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.6045 ± 0.3192
#   norm_S:  0.4829 ± 0.3048
#   score_R: 0.4762 ± 0.3046
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 30.12
#   Raw DCCW:      27.82 ± 12.54
#   Diversity Δ:   12.68
#
# ──────────────────────────────────────────────────
# Model: gpt-4o-mini
# Provider: openai
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.5688 ± 0.3167
#   norm_S:  0.4707 ± 0.2829
#   score_R: 0.4539 ± 0.2811
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 33.06
#   Raw DCCW:      27.95 ± 11.41
#   Diversity Δ:   13.45
#
# ──────────────────────────────────────────────────
# Model: gpt-4o
# Provider: openai
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.5839 ± 0.3074
#   norm_S:  0.5190 ± 0.2881
#   score_R: 0.4756 ± 0.2842
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 31.91
#   Raw DCCW:      26.11 ± 11.14
#   Diversity Δ:   13.08
#
# ──────────────────────────────────────────────────
# Model: gpt-5-mini
# Provider: openai
# ──────────────────────────────────────────────────
# Total samples: 100
# Valid samples: 100 (100.0%)
# Filtered out:  0
#
# Normalized Metrics (mean ± std):
#   norm_D:  0.5339 ± 0.3471
#   norm_S:  0.5586 ± 0.2625
#   score_R: 0.4662 ± 0.3014
#
# Raw Scores:
#   GT Diversity:  27.52
#   Gen Diversity: 35.68
#   Raw DCCW:      24.69 ± 10.43
#   Diversity Δ:   14.58

# %%
# Compare models side by side (best score_R highlighted)
comparison = summary_df[[
    'model', 'provider', 'valid_samples', 
    'mean_score_R', 'mean_norm_D', 'mean_norm_S',
    # 'mean_gt_diversity', 'mean_gen_diversity', 'mean_raw_dccw', 'mean_diversity_diff'
]].copy()
comparison = comparison.dropna(subset=['mean_score_R'])
comparison = comparison.sort_values('mean_score_R', ascending=False)

print("\n" + "=" * 80)
print("MODEL COMPARISON (sorted by score_R)")
print("=" * 80)

comparison
# Out:
# ================================================================================
# MODEL COMPARISON (sorted by score_R)
# ================================================================================
#                             model   provider  valid_samples  mean_score_R  \
# 3         llama-v3p3-70b-instruct  fireworks             88      0.479140
# 2      llama-v3p1-8b-instruct_HSL  fireworks             99      0.477468
# 7                    qwen3-8b_HSL  fireworks             99      0.477468
# 12         artist-v3-llama-3p1-8b  fireworks            100      0.476185
# 0                     gpt-oss-20b  fireworks             78      0.475971
# 14                         gpt-4o     openai            100      0.475552
# 11                      artist-v2  fireworks            100      0.472248
# 8       rft-fhiaqwgu-0-1-ka2pgv73  fireworks            100      0.468576
# 15                     gpt-5-mini     openai            100      0.466177
# 10          artist-qwen3-8b-5-5-8  fireworks            100      0.464881
# 6                 qwen3-8b_CIELAB  fireworks            100      0.458340
# 1          llama-v3p1-8b-instruct  fireworks            100      0.457575
# 13                    gpt-4o-mini     openai            100      0.453859
# 5                        qwen3-8b  fireworks            100      0.435674
# 4         qwen2p5-vl-32b-instruct  fireworks            100      0.414670
# 9   artist-qwen2p5-vl-7b-instruct  fireworks            100      0.388528
#
#     mean_norm_D  mean_norm_S
# 3      0.601410     0.502575
# 2      0.615814     0.478072
# 7      0.615814     0.478072
# 12     0.604483     0.482864
# 0      0.588642     0.532236
# 14     0.583893     0.518969
# 11     0.607634     0.494418
# 8      0.622311     0.488868
# 15     0.533857     0.558584
# 10     0.638413     0.459637
# 6      0.605522     0.470463
# 1      0.619746     0.462084
# 13     0.568782     0.470680
# 5      0.623319     0.440834
# 4      0.529314     0.463592
# 9      0.562037     0.415719

# %%
# Compare models side by side (best score_R highlighted)
comparison = summary_df[[
    'model', 'provider', 'valid_samples', 
    'mean_norm_S', 'mean_score_R', 'mean_norm_D',
    # 'mean_gt_diversity', 'mean_gen_diversity', 'mean_raw_dccw', 'mean_diversity_diff'
]].copy()
comparison = comparison.dropna(subset=['mean_norm_S'])
comparison = comparison.sort_values('mean_norm_S', ascending=False)

print("\n" + "=" * 80)
print("MODEL COMPARISON (sorted by norm_S)")
print("=" * 80)

comparison
# Out:
# ================================================================================
# MODEL COMPARISON (sorted by norm_S)
# ================================================================================
#                             model   provider  valid_samples  mean_norm_S  \
# 15                     gpt-5-mini     openai            100     0.558584
# 0                     gpt-oss-20b  fireworks             78     0.532236
# 14                         gpt-4o     openai            100     0.518969
# 3         llama-v3p3-70b-instruct  fireworks             88     0.502575
# 11                      artist-v2  fireworks            100     0.494418
# 8       rft-fhiaqwgu-0-1-ka2pgv73  fireworks            100     0.488868
# 12         artist-v3-llama-3p1-8b  fireworks            100     0.482864
# 2      llama-v3p1-8b-instruct_HSL  fireworks             99     0.478072
# 7                    qwen3-8b_HSL  fireworks             99     0.478072
# 13                    gpt-4o-mini     openai            100     0.470680
# 6                 qwen3-8b_CIELAB  fireworks            100     0.470463
# 4         qwen2p5-vl-32b-instruct  fireworks            100     0.463592
# 1          llama-v3p1-8b-instruct  fireworks            100     0.462084
# 10          artist-qwen3-8b-5-5-8  fireworks            100     0.459637
# 5                        qwen3-8b  fireworks            100     0.440834
# 9   artist-qwen2p5-vl-7b-instruct  fireworks            100     0.415719
#
#     mean_score_R  mean_norm_D
# 15      0.466177     0.533857
# 0       0.475971     0.588642
# 14      0.475552     0.583893
# 3       0.479140     0.601410
# 11      0.472248     0.607634
# 8       0.468576     0.622311
# 12      0.476185     0.604483
# 2       0.477468     0.615814
# 7       0.477468     0.615814
# 13      0.453859     0.568782
# 6       0.458340     0.605522
# 4       0.414670     0.529314
# 1       0.457575     0.619746
# 10      0.464881     0.638413
# 5       0.435674     0.623319
# 9       0.388528     0.562037
