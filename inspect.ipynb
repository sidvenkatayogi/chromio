# %%
import pandas
import pickle

file_path = "hexcolor_vf/test_names.pkl"

with open(file_path, 'rb') as file:
    data = pickle.load(file)

print(data)
# Out:
# [['communism'], ['dark', 'neon'], ['dont', 'talk', 'to', 'me'], ['good', 'night', 'princess'], ['good', 'morning', 'princess'], ['dusty', 'blue'], ['skin', 'sample'], ['soft', 'fall'], ['camilla', 'at', 'the', 'beach'], ['wedding'], ['roses', 'bouquet'], ['bakery'], ['pale', 'peach'], ['plums', 'and', 'moons'], ['fishermans', 'dream'], ['tenderness'], ['perfect', 'day'], ['wooden', 'path'], ['little', 'mermaid'], ['exuberance'], ['pink', 'ladies'], ['sandy'], ['almost', 'morning'], ['clear', 'thoughts'], ['midsummer', 'night', 'dream'], ['aqua', 'aura'], ['the', 'arrows', 'of', 'love'], ['pastel', 'play'], ['fly', 'away'], ['meaningless', 'apologies'], ['late', 'summer', 'festival'], ['clay'], ['siren', 'dreams'], ['french', 'countryside'], ['sunday', 'afternoon'], ['mountains', 'calling'], ['living', 'room'], ['love'], ['so', 'cold'], ['i', 'love', 'you'], ['beachy', 'day'], ['ice', 'cream'], ['sea', 'side'], ['aquamarine', 'nights'], ['autumnal', 'breeze'], ['royal', 'twilight'], [
# ...

# %%
file_path = "hexcolor_vf/test_palettes_rgb.pkl"

with open(file_path, 'rb') as file:
    data = pickle.load(file)

print(data)
# Out:
# [[(206, 18, 18), (193, 27, 27), (201, 149, 149), (191, 138, 138), (165, 27, 27)], [(116, 35, 35), (117, 122, 37), (35, 118, 41), (44, 41, 114), (115, 36, 116)], [(192, 237, 251), (192, 221, 235), (192, 205, 219), (192, 189, 203), (192, 173, 187)], [(49, 40, 66), (65, 55, 84), (87, 73, 105), (120, 100, 131), (156, 137, 161)], [(246, 245, 230), (244, 236, 217), (244, 226, 204), (240, 208, 186), (234, 189, 169)], [(217, 224, 236), (203, 220, 231), (160, 169, 178), (102, 105, 108), (37, 37, 37)], [(245, 218, 204), (237, 191, 166), (211, 141, 111), (154, 91, 64), (89, 59, 43)], [(201, 105, 107), (240, 184, 87), (218, 233, 252), (217, 174, 168), (138, 81, 36)], [(244, 129, 78), (251, 179, 90), (253, 242, 137), (191, 225, 229), (144, 189, 195)], [(218, 226, 227), (158, 181, 184), (238, 222, 213), (227, 183, 159), (206, 154, 126)], [(238, 221, 208), (221, 188, 179), (208, 167, 160), (103, 116, 105), (148, 176, 162)], [(240, 215, 167), (195, 121, 96), (137, 78, 63), (238, 225, 186), (156, 99,
# ...
